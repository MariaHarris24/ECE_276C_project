# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
import torch.nn.functional as F
#environment
import gym
import os
import time
#pytorch
import torch
from torch.autograd import Variable
import torch.nn as nn
from math import sqrt
import copy


logging_interval = 40
animate_interval = logging_interval * 5
logdir='./DDPG/'
VISUALIZE = False
SEED = 0
MAX_PATH_LENGTH = 500
NUM_EPISODES = 100000
GAMMA=0.99
BATCH_SIZE = 128

# Environments to be tested on
#env_name = 'InvertedDoublePendulum-v1'
#env_name = 'Pendulum-v0'
#env_name = 'HalfCheetah-v1' 
#env_name = 'MountainCarContinuous-v0'
env_name = 'Walker2d-v2'
#env_name = 'Ant-v1'



# wrap gym to save videos
env = gym.make(env_name)
env1 = gym.make(env_name)
env2 = gym.make(env_name)
env3 = gym.make(env_name)

if VISUALIZE:
    if not os.path.exists(logdir):
        os.mkdir(logdir)
    env1 = gym.wrappers.Monitor(env1, logdir, force=True, video_callable=lambda episode_id: episode_id%logging_interval==0)
env1._max_episodes_steps = MAX_PATH_LENGTH

# check observation and action space
discrete = isinstance(env.action_space, gym.spaces.Discrete)
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.n if discrete else env.action_space.shape[0]

if discrete:
    print("This is a discrete action space, probably not the right algorithm to use")

# set random seeds
torch.manual_seed(SEED)
np.random.seed(SEED)

# make variable types for automatic setting to GPU or CPU, depending on GPU availability
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor

# %%
class NormalizeAction(gym.ActionWrapper):
    def action(self, action):
        action = (action + 1) / 2  
        action *= (self.action_space.high - self.action_space.low)
        action += self.action_space.low
        return action

    def reverse_action(self, action):
        action -= self.action_space.low
        action /= (self.action_space.high - self.action_space.low)
        a
        ction = action * 2 - 1
        return actions

def weightSync(target_model, source_model, tau = 0.001):
    for parameter_target, parameter_source in zip(target_model.parameters(), source_model.parameters()):
        parameter_target.data.copy_((1 - tau) * parameter_target.data + tau * parameter_source.data)
        
class OrnsteinUhlenbeckProcess:
    def __init__(self, mu=np.zeros(act_dim), sigma=0.05, theta=.25, dimension=1e-2, x0=None,num_steps=12000):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dimension
        self.x0 = x0
        self.reset()

    def step(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

# %%
class AdaptiveParamNoiseSpec(object):
    def __init__(self, initial_stddev=0.1, desired_action_stddev=0.2, adaptation_coefficient=1.01):
        """
        Note that initial_stddev and current_stddev refer to std of parameter noise, 
        but desired_action_stddev refers to (as name notes) desired std in action space
        """
        self.initial_stddev = initial_stddev
        self.desired_action_stddev = desired_action_stddev
        self.adaptation_coefficient = adaptation_coefficient

        self.current_stddev = initial_stddev

    def adapt(self, distance):
        if distance > self.desired_action_stddev:
            # Decrease stddev.
            self.current_stddev /= self.adaptation_coefficient
        else:
            # Increase stddev.
            self.current_stddev *= self.adaptation_coefficient

    def get_stats(self):
        stats = {
            'param_noise_stddev': self.current_stddev,
        }
        return stats

    def __repr__(self):
        fmt = 'AdaptiveParamNoiseSpec(initial_stddev={}, desired_action_stddev={}, adaptation_coefficient={})'
        return fmt.format(self.initial_stddev, self.desired_action_stddev, self.adaptation_coefficient)

def ddpg_distance_metric(actions1, actions2):
    """
    Compute "distance" between actions taken by two policies at the same states
    Expects numpy arrays
    """
    diff = actions1-actions2
    mean_diff = np.mean(np.square(diff), axis=0)
    dist = sqrt(np.mean(mean_diff))
    return dist


def hard_update(target, source):
    for target_param, param in zip(target.parameters(), source.parameters()):
           target_param.data.copy_(param.data)

# %%
import random

class Replay(object):
    def __init__(self, maxlen = 60000):
        self.maxlen = maxlen
        #self.data = deque(maxlen = self.maxlen)
        self.data=[]
        self.position=0
#         self.initialize(init_length=1000, envir=env)
        
    def initialize(self,init_length=1000, envir=env):
        s = envir.reset()
        for i in range (init_length):
            #a = np.random.random(1)-np.random.random(1)
            a = env.action_space.sample()
            s1, r, done, _ = env.step(a)            
            self.add((s,a,r,s1,done))
                        
            if done:
                s=envir.reset()
            else: 
                s = s1  
              
    def add(self, ep):
        self.data.append(ep)
        self.position = (self.position + 1) % self.maxlen       
        #self.data[self.position] = tuple(ep)
        
    def sample(self, batch_size):     
        return random.sample(self.data, batch_size)

# %%
class critic(nn.Module):

    def __init__(self, state_size, action_size,output_size=1 ):
        super(critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_size + action_size, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_size + action_size, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2
    
    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class actor(nn.Module):

    def __init__(self, input_size, output_size):
        super(actor, self).__init__()

        self.state_dim = input_size
        self.action_dim = output_size
        h1_dim = 400
        h2_dim = 400
        self.fc1 = nn.Linear(self.state_dim, h1_dim)
        #self.bn1 = nn.BatchNorm1d(h1_dim)
        self.fc2 = nn.Linear(h1_dim, h2_dim)
        #self.bn2 = nn.BatchNorm1d(h2_dim)
        self.fc3 = nn.Linear(h2_dim, self.action_dim)

    def forward(self, state):
        #x = F.relu(self.bn1(self.fc1(state)))
        #x = F.relu(self.bn2(self.fc2(x)))
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        action = F.tanh(self.fc3(x))
        return action

# %%
class DDPG:
    def __init__(self, obs_dim, act_dim, max_action,critic_lr = 1e-3, actor_lr = 1e-4, gamma = GAMMA, batch_size = BATCH_SIZE):
        
        self.gamma = GAMMA
        self.batch_size = BATCH_SIZE
        
        # actor
        self.actor = actor(input_size = obs_dim, output_size = act_dim).type(FloatTensor)
        self.actor_perturbed = actor(input_size = obs_dim, output_size = act_dim).type(FloatTensor)
        self.actor_target = actor(input_size = obs_dim, output_size = act_dim).type(FloatTensor)
        self.actor_target.load_state_dict(self.actor.state_dict())

        # critic
        self.critic = critic(state_size = obs_dim, action_size = act_dim, output_size = 1).type(FloatTensor)
        self.critic_target = critic(state_size = obs_dim, action_size = act_dim, output_size = 1).type(FloatTensor)
        self.critic_target.load_state_dict(self.critic.state_dict())
        self.max_action=max_action
        
        if use_cuda:
            self.actor.cuda()
            self.actor_target.cuda()
            self.critic.cuda()
            self.critic_target.cuda()
            
        # optimizers
        self.optimizer_actor = torch.optim.Adam(self.actor.parameters(), lr = actor_lr)
        self.optimizer_critic = torch.optim.Adam(self.critic.parameters(), lr = critic_lr, weight_decay=1e-2)
        
        # critic loss
        self.critic_loss = nn.MSELoss()
        
        # noise
        self.noise = OrnsteinUhlenbeckProcess(dimension = act_dim, num_steps = NUM_EPISODES)
    
    def action(self, s, noise, para):
        obs = torch.from_numpy(s).unsqueeze(0)
        inp = Variable(obs,requires_grad=False).type(FloatTensor)

        self.actor.eval()
        self.actor_perturbed.eval()

        if para is not None:
            a = self.actor_perturbed(inp).data[0].cpu().numpy() 
        else:
            a = self.actor(inp).data[0].cpu().numpy() 
        self.actor.train()

        if noise is not None:
            a = a + noise
        return a
    
    def perturb_actor_parameters(self, param_noise):
        """Apply parameter noise to actor model, for exploration"""
        hard_update(self.actor_perturbed, self.actor)
        params = self.actor_perturbed.state_dict()
        for name in params:
            if 'ln' in name: 
                pass 
            param = params[name]
            random = torch.randn(param.shape)
            if use_cuda:
                random = random.cuda()
            param += random * param_noise.current_stddev
            
    def train(self, training_data,it):
        batch_s,batch_a,batch_r,batch_s1,batch_done=zip(*training_data)
        s1 = Variable(FloatTensor(batch_s))
        a1 = Variable(FloatTensor(batch_a))
        r1 = Variable(FloatTensor(np.array(batch_r).reshape(-1,1)))
        s2 = Variable(FloatTensor(batch_s1))
        d  = Variable(FloatTensor(1.0*np.array(batch_done).reshape(-1,1)))
        
        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (torch.randn_like(a1) * 0.2).clamp(-0.5, 0.5)

            next_action = (self.actor_target(s2) + noise).clamp(-self.max_action, self.max_action)
            
            q1_target,q2_target = self.critic_target(s2, next_action)
            next_val = torch.min(q1_target,q2_target)
            q_expected = r1 + self.gamma*next_val*(1.0-d)
        
        q1_predicted, q2_predicted = self.critic(s1, a1)
        
        # compute critic loss, and update the critic
        loss_critic = F.mse_loss(q1_predicted,q_expected)+F.mse_loss(q2_predicted,q_expected)
        self.optimizer_critic.zero_grad()
        loss_critic.backward()
        self.optimizer_critic.step()
        
        if it%2==0:
            pred_a1 = self.actor.forward(s1)
            loss_actor = -1*self.critic.Q1(s1, pred_a1).mean()
            #loss_actor = loss_actor.mean()

            self.optimizer_actor.zero_grad()
            loss_actor.backward()
            self.optimizer_actor.step()

            # sychronize target network with fast moving one
            weightSync(self.critic_target, self.critic)
            weightSync(self.actor_target, self.actor)

# %%
ddpg1 = DDPG(obs_dim = obs_dim, act_dim = act_dim,max_action=float(env.action_space.high[0]))
ddpg2 = DDPG(obs_dim = obs_dim, act_dim = act_dim,max_action=float(env.action_space.high[0]))
ddpg3 = DDPG(obs_dim = obs_dim, act_dim = act_dim,max_action=float(env.action_space.high[0]))
memory = Replay(60000)
memory.initialize(init_length=150, envir=env)

# %%
#env = NormalizeAction(env) # remap action values for the environment
avg_val = 0


env1 = NormalizeAction(env1)
env2 = NormalizeAction(env2)
env3 = NormalizeAction(env3)

#for plotting
running_rewards_ddpg = []
step_list_ddpg = []
step_count = 0
total_rewards=[]
# set term_condition for early stopping according to environment being used
term_condition = -150 # Pendulum
#term_condition = 500 # inverted Pendulum
#term_condition = 8500 # half cheetah

param_noise = AdaptiveParamNoiseSpec(initial_stddev=0.05,desired_action_stddev=0.3, adaptation_coefficient=1.05)
print(param_noise)

for itr in range(NUM_EPISODES):
    s1 = env1.reset() # get initial state
    s2 = env2.reset()
    s3 = env3.reset()
    total_reward = [0, 0]
    step_counter = [0,0]
    
    noise_counter=0
    ddpg1.perturb_actor_parameters(param_noise)
    ddpg2.perturb_actor_parameters(param_noise)
    ddpg3.perturb_actor_parameters(param_noise)
    
    done1 = 0
    done2 = 0
    done3 = 0
    
    while True:
        
        if not done1:
            ddpg1.noise.reset()
            a1 = ddpg1.action(s1, ddpg1.noise.step(), param_noise)
            s1_1, r1, done1, _ = env1.step(a1)
            memory.add((s1,a1,r1,s1_1,done1))
            total_reward[0] += r1
            step_counter[0] += 1
            training_data1 = np.array(memory.sample(BATCH_SIZE))
            ddpg1.train(training_data1,itr)
            noise_counter += 1
            s1 = s1_1
            
        if not done2:
            ddpg2.noise.reset()
            a2 = ddpg2.action(s2, ddpg2.noise.step(), param_noise)
            
            s1_2, r2, done2, _ = env2.step(a2)
            memory.add((s2,a2,r2,s1_2,done2))
            total_reward[1] += r2
            step_counter[1] += 1
            training_data2 = np.array(memory.sample(BATCH_SIZE))
            ddpg2.train(training_data2,itr)
            noise_counter += 1
            s2 = s1_2
            
#         if not done3:
#             ddpg3.noise.reset()
#             a3 = ddpg3.action(s3, ddpg3.noise.step(), param_noise)
            
#             s1_3, r3, done3, _ = env3.step(a3)
#             memory.add((s3,a3,r3,s1_3,done3))
#             total_reward[2] += r3
            
#             step_counter[2] += 1
#             training_data3 = np.array(memory.sample(BATCH_SIZE))
#             ddpg3.train(training_data3)
#             noise_counter += 1
#             s3 = s1_3
            
        if done1 and done2:
            break
            
            
    ddpgs = [ddpg1, ddpg2]
    total_rewards.append(total_reward)
    idx = np.array(total_reward).argmax()
    myddpg = ddpgs[idx]

    ddpg1 = copy.deepcopy(myddpg)
    ddpg2 = copy.deepcopy(myddpg)
    ddpg3 = copy.deepcopy(myddpg)

    

    if memory.position-noise_counter > 0:
        noise_data=memory.data[memory.position-noise_counter:memory.position]
    else:
        noise_data=memory.data[memory.position-noise_counter+60000:60000] \
        + memory.data[0:memory.position]
        
    
    noise_data=np.array(noise_data)
    noise_s, noise_a, _,_ , _= zip(*noise_data)
    
    perturbed_actions = noise_a
    unperturbed_actions = myddpg.action(np.array(noise_s), None, None)
    ddpg_dist = ddpg_distance_metric(perturbed_actions, unperturbed_actions)
    param_noise.adapt(ddpg_dist)
    
    
    #if itr > 3 and avg_val > term_condition:
     #   break
    running_rewards_ddpg.append(total_reward[idx]) # return of this episode
    step_count = step_count + step_counter[idx]
    step_list_ddpg.append(step_count)
    if itr%10==0:
        avg_val = avg_val * 0.95 + 0.05*running_rewards_ddpg[-1]
        print("Average value: {} for episode: {}".format(avg_val,itr))
# Out:
# AdaptiveParamNoiseSpec(initial_stddev=0.05, desired_action_stddev=0.3, adaptation_coefficient=1.05)
# /home/mariaharris44/anaconda3/envs/gymvenv/lib/python3.7/site-packages/ipykernel_launcher.py:47: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /home/mariaharris44/anaconda3/envs/gymvenv/lib/python3.7/site-packages/ipykernel_launcher.py:60: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /home/mariaharris44/anaconda3/envs/gymvenv/lib/python3.7/site-packages/ipykernel_launcher.py:101: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Average value: -0.28470552659339265 for episode: 0
# Average value: -0.29017165282605595 for episode: 10
# Average value: -0.11488046832996743 for episode: 20
# Average value: 7.19370388882391 for episode: 30
# Average value: 20.02212414332411 for episode: 40
# Average value: 23.952930802308394 for episode: 50
# Average value: 25.64268757540975 for episode: 60
# Average value: 38.25933642365635 for episode: 70
# Average value: 50.39495269999863 for episode: 80
# Average value: 51.60865585333019 for episode: 90
# Average value: 54.79215235044481 for episode: 100
# Average value: 55.83685488495961 for episode: 110
# Average value: 70.10169981299255 for episode: 120
# Average value: 113.12364832315518 for episode: 130
# Average value: 123.7566385791666 for episode: 140
# Average value: 122.15681448251897 for episode: 150
# Average value: 121.58240326746709 for episode: 160
# Average value: 131.62187478096322 for episode: 170
# Average value: 129.26665225543942 for episode: 180
# Average value: 126.75596661965702 for episode: 190
# Average value: 138.12556682000033 for episode: 200
# Average value: 143.311758103213 for episode: 210
# Average value: 152.59105578747548 for episode: 220
# Average value: 158.73754244998383 for episode: 230
# Average value: 163.31180024497698 for episode: 240
# Average value: 169.0735999702309 for episode: 250
# Average value: 174.7822135518997 for episode: 260
# Average value: 189.3109771251674 for episode: 270
# Average value: 193.2187590218733 for episode: 280
# Average value: 197.7707753465974 for episode: 290
# Average value: 203.4588171513809 for episode: 300
# Average value: 207.29316879635795 for episode: 310
# Average value: 212.3214418200945 for episode: 320
# Average value: 215.8558274612075 for episode: 330
# Average value: 213.34002098215603 for episode: 340
# Average value: 210.08432889660727 for episode: 350
# Average value: 205.04112416164259 for episode: 360
# Average value: 213.04277121625023 for episode: 370
# Average value: 220.61012408961787 for episode: 380
# Average value: 220.7970887795846 for episode: 390
# Average value: 223.04438093665547 for episode: 400
# Average value: 237.09576744632832 for episode: 410
# Average value: 244.00341839996503 for episode: 420
# Average value: 249.45671175640786 for episode: 430
# Average value: 261.65210658948536 for episode: 440
# Average value: 268.3224467911008 for episode: 450
# Average value: 279.4170435508404 for episode: 460
# Average value: 289.0851639072229 for episode: 470
# Average value: 305.4048448945143 for episode: 480
# Average value: 317.1400932538515 for episode: 490
# Average value: 319.4840496915553 for episode: 500
# Average value: 314.4221059071817 for episode: 510
# Average value: 308.48230960449587 for episode: 520
# Average value: 317.49559500706874 for episode: 530
# Average value: 312.7606267158832 for episode: 540
# Average value: 306.61246778910436 for episode: 550
# Average value: 300.4829284160326 for episode: 560
# Average value: 307.5409717593374 for episode: 570
# Average value: 300.43189695757076 for episode: 580
# Average value: 294.63798558967187 for episode: 590
# Average value: 306.5208850018592 for episode: 600
# Average value: 299.65470288161856 for episode: 610
# Average value: 292.5370793360717 for episode: 620
# Average value: 308.0033692458991 for episode: 630
# Average value: 313.99970254926916 for episode: 640
# Average value: 320.6865854415754 for episode: 650
# Average value: 330.6063784453097 for episode: 660
# Average value: 331.4543324107114 for episode: 670
# Average value: 324.0312197436774 for episode: 680
# Average value: 316.6046069386175 for episode: 690
# Average value: 311.28650830010736 for episode: 700
# Average value: 310.7476246340576 for episode: 710
# Average value: 315.0082522598072 for episode: 720
# Average value: 329.5546751125228 for episode: 730
# Average value: 322.0712327718344 for episode: 740
# Average value: 315.00573177589973 for episode: 750
# Average value: 308.0559430435557 for episode: 760
# Average value: 302.06443070697406 for episode: 770
# Average value: 296.02915215957364 for episode: 780
# Average value: 300.63833152566326 for episode: 790
# Average value: 318.8645686451767 for episode: 800
# Average value: 311.1448632556928 for episode: 810
# Average value: 305.9414344633603 for episode: 820
# Average value: 306.5684398166866 for episode: 830
# Average value: 324.89258276130795 for episode: 840
# Average value: 329.08428824239365 for episode: 850
# Average value: 330.75837173446087 for episode: 860
# Average value: 336.14087021242926 for episode: 870
# Average value: 329.12013000077013 for episode: 880
# Average value: 323.7845287294189 for episode: 890
# Average value: 339.52880902988466 for episode: 900
# Average value: 351.7911031045445 for episode: 910
# Average value: 359.61742305160027 for episode: 920
# Average value: 364.1722001154485 for episode: 930
# Average value: 366.04814511336707 for episode: 940
# Average value: 373.2387129307044 for episode: 950
# Average value: 369.66869764769507 for episode: 960
# Average value: 383.00624959744005 for episode: 970
# Average value: 390.2534387032696 for episode: 980
# Average value: 404.1389278965818 for episode: 990
# Average value: 396.34609460138233 for episode: 1000
# Average value: 406.41976457848534 for episode: 1010
# Average value: 419.02591012475807 for episode: 1020
# Average value: 425.714271187383 for episode: 1030
# Average value: 430.45027353524307 for episode: 1040
# Average value: 443.2139516746332 for episode: 1050
# Average value: 441.0807539991777 for episode: 1060
# Average value: 444.02915027147657 for episode: 1070
# Average value: 450.9388768457343 for episode: 1080
# Average value: 466.7859387533705 for episode: 1090
# Average value: 472.6266779572846 for episode: 1100
# Average value: 479.69007888859363 for episode: 1110
# Average value: 484.4937641381925 for episode: 1120
# Average value: 498.3841340010831 for episode: 1130
# Average value: 503.7749385130907 for episode: 1140
# Average value: 517.7835613816392 for episode: 1150
# Average value: 517.103551977708 for episode: 1160
# Average value: 529.4376731466331 for episode: 1170
# Average value: 539.386595605421 for episode: 1180
# Average value: 552.7748821443422 for episode: 1190
# Average value: 532.8005804275799 for episode: 1200
# Average value: 534.0029224725193 for episode: 1210
# Average value: 549.521474271413 for episode: 1220
# Average value: 561.9339780823956 for episode: 1230
# Average value: 563.4838585961903 for episode: 1240
# Average value: 566.7401080377315 for episode: 1250
# Average value: 576.6545210539733 for episode: 1260
# Average value: 592.8970250172041 for episode: 1270
# Average value: 591.0192183331616 for episode: 1280
# Average value: 608.5540263997395 for episode: 1290
# Average value: 612.4261915704965 for episode: 1300
# Average value: 617.137870091748 for episode: 1310
# Average value: 622.5276537770709 for episode: 1320
# Average value: 621.5678099822175 for episode: 1330
# Average value: 631.6554284892005 for episode: 1340
# Average value: 624.6148163339438 for episode: 1350
# Average value: 617.8957416264936 for episode: 1360
# Average value: 617.5049989818413 for episode: 1370
# Average value: 621.4852911747423 for episode: 1380
# Average value: 617.0916835832812 for episode: 1390
# Average value: 613.2576538609767 for episode: 1400
# Average value: 621.113639844879 for episode: 1410
# Average value: 612.8404714864278 for episode: 1420
# Average value: 610.5160771269718 for episode: 1430
# Average value: 620.3850233447124 for episode: 1440
# Average value: 619.4343327281277 for episode: 1450
# Average value: 618.6649114955312 for episode: 1460
# Average value: 628.8918095922875 for episode: 1470
# Average value: 622.8564987972954 for episode: 1480
# Average value: 621.315274671853 for episode: 1490
# Average value: 632.7358867835464 for episode: 1500
# Average value: 638.3569380291808 for episode: 1510
# Average value: 613.7520325699129 for episode: 1520
# Average value: 622.539965848726 for episode: 1530
# Average value: 615.1640611045605 for episode: 1540
# Average value: 625.33488664879 for episode: 1550
# Average value: 636.6989094393465 for episode: 1560
# Average value: 642.7299148551408 for episode: 1570
# Average value: 654.5854615884782 for episode: 1580
# Average value: 656.6167050217152 for episode: 1590
# Average value: 674.2265515708493 for episode: 1600
# Average value: 685.0482257936392 for episode: 1610
# Average value: 687.861209119044 for episode: 1620
# Average value: 698.4173234633299 for episode: 1630
# Average value: 709.5120085035495 for episode: 1640
# Average value: 709.5908642963063 for episode: 1650
# Average value: 726.0266553449699 for episode: 1660
# Average value: 730.595234692926 for episode: 1670
# Average value: 736.9497970617962 for episode: 1680
# Average value: 739.0954512212807 for episode: 1690
# Average value: 748.1964103989161 for episode: 1700
# Average value: 742.4735742042216 for episode: 1710
# Average value: 740.727330810114 for episode: 1720
# Average value: 750.6629093601555 for episode: 1730
# Average value: 751.2307546336673 for episode: 1740
# Average value: 757.6567503851567 for episode: 1750
# Average value: 776.426756175161 for episode: 1760
# Average value: 781.0527039121514 for episode: 1770
# Average value: 782.9583549863142 for episode: 1780
# Average value: 796.640882787648 for episode: 1790
# Average value: 801.2266713760906 for episode: 1800
# Average value: 798.9854964983152 for episode: 1810
# Average value: 845.4257970233696 for episode: 1820
# Average value: 848.4889396218027 for episode: 1830
# Average value: 848.3667434499188 for episode: 1840
# Average value: 837.6709707799947 for episode: 1850
# Average value: 854.0866637966592 for episode: 1860
# Average value: 874.3397483566785 for episode: 1870
# Average value: 872.8840577423343 for episode: 1880
# Average value: 881.1372105359868 for episode: 1890
# Average value: 896.5259179208131 for episode: 1900
# Average value: 903.1054655915955 for episode: 1910
# Average value: 923.0622582234458 for episode: 1920
# Average value: 985.1942182700188 for episode: 1930
# Average value: 993.4280339427442 for episode: 1940
# Average value: 996.7495069843214 for episode: 1950
# Average value: 1076.9669781588796 for episode: 1960
# Average value: 1176.2126673821701 for episode: 1970
# Average value: 1286.5666928823694 for episode: 1980
# Average value: 1271.1429974856073 for episode: 1990
# Average value: 1394.4860517956477 for episode: 2000
# Average value: 1376.1877764409537 for episode: 2010
# Average value: 1385.4647436094042 for episode: 2020
# Average value: 1401.8364774958475 for episode: 2030
# Average value: 1439.690260874653 for episode: 2040
# Average value: 1496.8881524596793 for episode: 2050
# Average value: 1507.0787694019814 for episode: 2060
# Average value: 1636.2774681655699 for episode: 2070
# Average value: 1627.781413772479 for episode: 2080
# Average value: 1602.3539004612599 for episode: 2090
# Average value: 1610.540270254944 for episode: 2100
# Average value: 1695.0161492321954 for episode: 2110
# Average value: 1701.5115655282866 for episode: 2120
# Average value: 1693.3437544505578 for episode: 2130
# Average value: 1686.4831840079073 for episode: 2140
# Average value: 1789.1447066689675 for episode: 2150
# Average value: 1884.9298572700225 for episode: 2160
# Average value: 1929.4718828523287 for episode: 2170
# Average value: 2048.133134507366 for episode: 2180
# Average value: 2092.9598338321293 for episode: 2190
# Average value: 2198.693814807059 for episode: 2200
# Average value: 2216.1379378842666 for episode: 2210
# Average value: 2292.633952633037 for episode: 2220
# Average value: 2389.3382050737064 for episode: 2230
# Average value: 2481.8475585159144 for episode: 2240
# Average value: 2561.6392409621876 for episode: 2250
# Average value: 2441.5369193409297 for episode: 2260
# Average value: 2550.1448135589117 for episode: 2270
# Average value: 2470.600367570852 for episode: 2280
# Average value: 2568.668515689205 for episode: 2290
# Average value: 2638.078955854026 for episode: 2300
# Average value: 2727.0725827194638 for episode: 2310
# Average value: 2810.9869616100827 for episode: 2320
# Average value: 2903.50015017109 for episode: 2330
# Average value: 2986.8379970892747 for episode: 2340
# Average value: 3058.04448446872 for episode: 2350
# Average value: 3119.4927427094594 for episode: 2360
# Average value: 3160.0804616002356 for episode: 2370
# Average value: 3231.5723050864276 for episode: 2380
# Average value: 3297.7666305647226 for episode: 2390
# Average value: 3351.6547065583013 for episode: 2400
# Average value: 3394.2089759797145 for episode: 2410
# Average value: 3444.0376641489243 for episode: 2420
# Average value: 3487.928274560366 for episode: 2430
# Average value: 3519.2223442158615 for episode: 2440
# Average value: 3570.9932958486693 for episode: 2450
# Average value: 3622.686057853085 for episode: 2460
# Average value: 3671.4121985632805 for episode: 2470
# Average value: 3710.3348888290484 for episode: 2480
# Average value: 3745.9889624860757 for episode: 2490
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-25-a3d3d240b7b6> in <module>
#      59             step_counter[1] += 1
#      60             training_data2 = np.array(memory.sample(BATCH_SIZE))
# ---> 61             ddpg2.train(training_data2,itr)
#      62             noise_counter += 1
#      63             s2 = s1_2
#
# <ipython-input-23-78936b3f150c> in train(self, training_data, it)
#      65     def train(self, training_data,it):
#      66         batch_s,batch_a,batch_r,batch_s1,batch_done=zip(*training_data)
# ---> 67         s1 = Variable(FloatTensor(batch_s))
#      68         a1 = Variable(FloatTensor(batch_a))
#      69         r1 = Variable(FloatTensor(np.array(batch_r).reshape(-1,1)))
#
# KeyboardInterrupt:

# %%
def numpy_ewma_vectorized_v2(data, window):

    alpha = 2 /(window + 1.0)
    alpha_rev = 1-alpha
    n = data.shape[0]

    pows = alpha_rev**(np.arange(n+1))

    scale_arr = 1/pows[:-1]
    offset = data[0]*pows[1:]
    pw0 = alpha*alpha_rev**(n-1)

    mult = data*pw0*scale_arr
    cumsums = mult.cumsum()
    out = offset + cumsums*scale_arr[::-1]
    return out

plt.figure()
out = numpy_ewma_vectorized_v2(np.array(running_rewards_ddpg),20)
step_list_ddpg = np.array(step_list_ddpg)

plt.plot(step_list_ddpg, out)
plt.title('Training reward over multiple runs')
plt.xlabel('Number of steps')
plt.ylabel('Cumulative reward')
plt.show()

# %%
np.save('out.npy',out)
np.save('step_list_ddpg.npy',step_list_ddpg)

# %%
torch.save(myddpg.actor, 'actor.pt')
torch.save(myddpg.actor_perturbed, 'actor_perturbed.pt')
np.save('param_noise.npy',[param_noise.desired_action_stddev,
                           param_noise.adaptation_coefficient,
                           param_noise.current_stddev])
# Out:
# /home/mariaharris44/anaconda3/envs/gymvenv/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type actor. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
pnl = np.load('param_noise.npy')
myddpg.actor = torch.load('actor.pt')
myddpg.actor_perturbed = torch.load('actor_perturbed.pt')

# %%
env_name =  'Walker2d-v2'
env4 = gym.make(env_name)

# check whether the environment is discrete or continuous
discrete = isinstance(env.action_space, gym.spaces.Discrete)
obs_dim = env4.observation_space.shape[0]
act_dim = env4.action_space.n if discrete else env.action_space.shape[0]
if discrete: print("This is a discrete action space, probably not the right algorithm to use")


logdir='./DDPG_final/'
logging_interval = 20
animate_interval = logging_interval * 5
VISUALIZE = True
if VISUALIZE:
    if not os.path.exists(logdir):
        os.mkdir(logdir)
    env4 = gym.wrappers.Monitor(env4, logdir, force=True, video_callable=lambda \
                               episode_id: episode_id%logging_interval==0)
env4._max_episodes_steps = MAX_PATH_LENGTH

env4 = NormalizeAction(env4) # remap action values for the environment

# %%
for i in range(2):
    SEED = 0   
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    s1 = env4.reset() # get initial state
    # env1.render()
    # time.sleep(0.05)
    count=0
    param_noise = AdaptiveParamNoiseSpec(pnl[2],pnl[0],pnl[1])
    while True: # for each episode, we loop each step in this episode
        myddpg.noise.reset()
        #env4.render()
        time.sleep(0.05)
        # use actor to get action, add ddpg.noise.step() to action
        # remember to put NN in eval mode while testing (to deal with BatchNorm layers) and put it back 
        # to train mode after you're done getting the action
        a1 = myddpg.action(s1, myddpg.noise.step(), param_noise)
        s1_1, r1, done1, _ = env4.step(a1)
        s1 = s1_1
        if done1: break
        count+=1
print('Finish Visualization')
# Out:
# /home/mariaharris44/anaconda3/envs/gymvenv/lib/python3.7/site-packages/torch/nn/functional.py:1339: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# --------------------------------------------------------------------------
# BrokenPipeError                          Traceback (most recent call last)
# <ipython-input-34-a13a4e9879bd> in <module>
#      16         # to train mode after you're done getting the action
#      17         a1 = myddpg.action(s1, myddpg.noise.step(), param_noise)
# ---> 18         s1_1, r1, done1, _ = env4.step(a1)
#      19         s1 = s1_1
#      20         if done1: break
#
# ~/anaconda3/envs/gymvenv/lib/python3.7/site-packages/gym/core.py in step(self, action)
#     290
#     291     def step(self, action):
# --> 292         return self.env.step(self.action(action))
#     293
#     294     def action(self, action):
#
# ~/anaconda3/envs/gymvenv/lib/python3.7/site-packages/gym/wrappers/monitor.py in step(self, action)
#      30         self._before_step(action)
#      31         observation, reward, done, info = self.env.step(action)
# ---> 32         done = self._after_step(observation, reward, done, info)
#      33
#      34         return observation, reward, done, info
#
# ~/anaconda3/envs/gymvenv/lib/python3.7/site-packages/gym/wrappers/monitor.py in _after_step(self, observation, reward, done, info)
#     169         self.stats_recorder.after_step(observation, reward, done, info)
#     170         # Record video
# --> 171         self.video_recorder.capture_frame()
#     172
#     173         return done
#
# ~/anaconda3/envs/gymvenv/lib/python3.7/site-packages/gym/wrappers/monitoring/video_recorder.py in capture_frame(self)
#     114                 self._encode_ansi_frame(frame)
#     115             else:
# --> 116                 self._encode_image_frame(frame)
#     117
#     118     def close(self):
#
# ~/anaconda3/envs/gymvenv/lib/python3.7/site-packages/gym/wrappers/monitoring/video_recorder.py in _encode_image_frame(self, frame)
#     164
#     165         try:
# --> 166             self.encoder.capture_frame(frame)
#     167         except error.InvalidFrame as e:
#     168             logger.warn('Tried to pass invalid video frame, marking as broken: %s', e)
#
# ~/anaconda3/envs/gymvenv/lib/python3.7/site-packages/gym/wrappers/monitoring/video_recorder.py in capture_frame(self, frame)
#     302
#     303         if distutils.version.LooseVersion(np.__version__) >= distutils.version.LooseVersion('1.9.0'):
# --> 304             self.proc.stdin.write(frame.tobytes())
#     305         else:
#     306             self.proc.stdin.write(frame.tostring())
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
count

# %%
out=np.load('out.npy')
step_list_ddpg=np.load('step_list_ddpg.npy')

plt.plot(step_list_ddpg, out)
plt.title('Training reward over multiple runs')
plt.xlabel('Number of steps')
plt.ylabel('Cumulative reward')
plt.show()
